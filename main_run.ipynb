# %%
import os

os.chdir(os.path.dirname(os.path.abspath("__file__")))

# %run ./data_extraction.ipynb
# %run ./data_transformation.ipynb
# %run ./exploration.ipynb

# %%
counts(data, 'Department')

# %%
salary_pie(data, 'Monthly_Salary', 'Department')

# %%
salary_bars(data, 'Monthly_Salary', 'City')

# %%
stacked_bar_100(data, 'Gender', 'Education_Level')

# %%
scatterplot(data, 'Experience_Years', 'Monthly_Salary', 'Department')
